# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as sem

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# File to Load (Remember to Change These)
mouse_drug_data_to_load = "data/mouse_drug_data.csv"
clinical_trial_data_to_load = "data/clinicaltrial_data.csv"

# Read the Mouse and Drug Data and the Clinical Trial Data
mouse_drug_data = pd.read_csv(mouse_drug_data_to_load, delimiter = ',')
clinical_trial_data = pd.read_csv(clinical_trial_data_to_load, delimiter = ',')

# mouse_drug_data.head()
# clinical_trial_data.head()


# Combine the data into a single dataset
combined_data = pd.merge(clinical_trial_data, mouse_drug_data,on ="Mouse ID",how='outer')

# Display the data table for preview
combined_data.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites       Drug
# 0     b128          0           45.000000                 0  Capomulin
# 1     b128          5           45.651331                 0  Capomulin
# 2     b128         10           43.270852                 0  Capomulin
# 3     b128         15           43.784893                 0  Capomulin
# 4     b128         20           42.731552                 0  Capomulin

# %% [markdown]
# ## Tumor Response to Treatment

# %%
# Store the Mean Tumor Volume Data Grouped by Drug and Timepoint 

tumor_mean =  combined_data.groupby(['Drug','Timepoint']).mean()['Tumor Volume (mm3)']
tumor_mean.head()

# Convert to DataFrame
tumor_mean = pd.DataFrame(data=tumor_mean)

# Preview DataFrame
tumor_mean.head()
# Out:
#                      Tumor Volume (mm3)
# Drug      Timepoint
# Capomulin 0                   45.000000
#           5                   44.266086
#           10                  43.084291
#           15                  42.064317
#           20                  40.716325

# %%
# Store the Standard Error of Tumor Volumes Grouped by Drug and Timepoint
tumor_sem = combined_data.groupby(["Drug", "Timepoint"]).sem()["Tumor Volume (mm3)"]

# Convert to DataFrame
tumor_sem = pd.DataFrame(tumor_sem)

# Preview DataFrame
tumor_sem.head()
# Out:
#                      Tumor Volume (mm3)
# Drug      Timepoint
# Capomulin 0                    0.000000
#           5                    0.448593
#           10                   0.702684
#           15                   0.838617
#           20                   0.909731

# %%
# Minor Data Munging to Re-Format the Data Frames 
#mean pivot table
tumor_mean_pivot = pd.pivot_table(combined_data, index='Timepoint', columns='Drug', values='Tumor Volume (mm3)', aggfunc = np.mean)

# Preview that Reformatting worked
tumor_mean_pivot
# Out:
# Drug       Capomulin   Ceftamin  Infubinol   Ketapril   Naftisol    Placebo  \
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000  45.000000  45.000000
# 5          44.266086  46.503051  47.062001  47.389175  46.796098  47.125589
# 10         43.084291  48.285125  49.403909  49.582269  48.694210  49.423329
# 15         42.064317  50.094055  51.296397  52.399974  50.933018  51.359742
# 20         40.716325  52.157049  53.197691  54.920935  53.644087  54.364417
# 25         39.939528  54.287674  55.715252  57.678982  56.731968  57.482574
# 30         38.769339  56.769517  58.299397  60.994507  59.559509  59.809063
# 35         37.816839  58.827548  60.742461  63.371686  62.685087  62.420615
# 40         36.958001  61.467895  63.162824  66.068580  65.600754  65.052675
# 45         36.236114  64.132421  65.755562  70.662958  69.265506  68.084082
#
# Drug        Propriva   Ramicane   Stelasyn  Zoniferol
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000
# ...

# %%
# Minor Data Munging to Re-Format the Data Frames 
#Standard Error pivot table
tumor_sem_pivot = pd.pivot_table(tumor_sem, index='Timepoint', columns='Drug', values='Tumor Volume (mm3)')

#preview
tumor_sem_pivot
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.448593  0.164505   0.235102  0.264819  0.202385  0.218091
# 10          0.702684  0.236144   0.282346  0.357421  0.319415  0.402064
# 15          0.838617  0.332053   0.357705  0.580268  0.444378  0.614461
# 20          0.909731  0.359482   0.476210  0.726484  0.595260  0.839609
# 25          0.881642  0.439356   0.550315  0.755413  0.813706  1.034872
# 30          0.934460  0.490620   0.631061  0.934121  0.975496  1.218231
# 35          1.052241  0.692248   0.984155  1.127867  1.013769  1.287481
# 40          1.223608  0.708505   1.055220  1.158449  1.118567  1.370634
# 45          1.223977  0.902358   1.144427  1.453186  1.416363  1.351726
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# ...

# %%
# Generate the Plot (with Error Bars)
plt.errorbar(tumor_mean_pivot.index, tumor_mean_pivot["Capomulin"], yerr=tumor_sem_pivot["Capomulin"], color="r", 
             marker="o", markersize=5, linestyle="dashed", linewidth=0.50)
plt.errorbar(tumor_mean_pivot.index, tumor_mean_pivot["Infubinol"], yerr=tumor_sem_pivot["Infubinol"], color="b", 
             marker="^", markersize=5, linestyle="dashed", linewidth=0.50)
plt.errorbar(tumor_mean_pivot.index, tumor_mean_pivot["Ketapril"], yerr=tumor_sem_pivot["Ketapril"], color="g", 
             marker="s", markersize=5, linestyle="dashed", linewidth=0.50)
plt.errorbar(tumor_mean_pivot.index, tumor_mean_pivot["Placebo"], yerr=tumor_sem_pivot["Placebo"], color="k", 
             marker="d", markersize=5, linestyle="dashed", linewidth=0.50)

plt.title("Tumor Response to Treatment")
plt.ylabel("Tumor Volume (mm3)")
plt.xlabel("Time (Days)")
plt.grid(True)
plt.legend(loc="best", fontsize="small", fancybox=True)

# Save the Figure
plt.savefig("Analysis/Fig1.png")

# Show the Figure
plt.show()

# %% [markdown]
# ## Metastatic Response to Treatment

# %%
# Store the Mean Met. Site Data Grouped by Drug and Timepoint 
met_sites_mean = combined_data.groupby(["Drug", "Timepoint"]).mean()["Metastatic Sites"]

# Convert to DataFrame
met_sites_mean = pd.DataFrame(met_sites_mean)

# Preview DataFrame
met_sites_mean.head()
# Out:
#                      Metastatic Sites
# Drug      Timepoint
# Capomulin 0                  0.000000
#           5                  0.160000
#           10                 0.320000
#           15                 0.375000
#           20                 0.652174

# %%
# Store the Standard Error associated with Met. Sites Grouped by Drug and Timepoint 
met_sites_sem = combined_data.groupby(["Drug", "Timepoint"]).sem()["Metastatic Sites"]

# Convert to DataFrame
met_sites_sem = pd.DataFrame(met_sites_sem)

# Preview DataFrame
met_sites_sem.head()
# Out:
#                      Metastatic Sites
# Drug      Timepoint
# Capomulin 0                  0.000000
#           5                  0.074833
#           10                 0.125433
#           15                 0.132048
#           20                 0.161621

# %%
# Minor Data Munging to Re-Format the Data Frames
#Mean Metstatic Sites data

met_mean_pivot = pd.pivot_table(met_sites_mean, index='Timepoint', columns='Drug', 
                                values='Metastatic Sites')

# Preview that Reformatting worked
met_mean_pivot
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.160000  0.380952   0.280000  0.304348  0.260870  0.375000
# 10          0.320000  0.600000   0.666667  0.590909  0.523810  0.833333
# 15          0.375000  0.789474   0.904762  0.842105  0.857143  1.250000
# 20          0.652174  1.111111   1.050000  1.210526  1.150000  1.526316
# 25          0.818182  1.500000   1.277778  1.631579  1.500000  1.941176
# 30          1.090909  1.937500   1.588235  2.055556  2.066667  2.266667
# 35          1.181818  2.071429   1.666667  2.294118  2.266667  2.642857
# 40          1.380952  2.357143   2.100000  2.733333  2.466667  3.166667
# 45          1.476190  2.692308   2.111111  3.363636  2.538462  3.272727
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# ...

# %%
# Minor Data Munging to Re-Format the Data Frames
#SEM Metstatic Sites data
met_sem_pivot = pd.pivot_table(met_sites_sem, index='Timepoint', columns='Drug', 
                               values='Metastatic Sites', aggfunc = np.mean)

# Preview that Reformatting worked
met_sem_pivot
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.074833  0.108588   0.091652  0.098100  0.093618  0.100947
# 10          0.125433  0.152177   0.159364  0.142018  0.163577  0.115261
# 15          0.132048  0.180625   0.194015  0.191381  0.158651  0.190221
# 20          0.161621  0.241034   0.234801  0.236680  0.181731  0.234064
# 25          0.181818  0.258831   0.265753  0.288275  0.185240  0.263888
# 30          0.172944  0.249479   0.227823  0.347467  0.266667  0.300264
# 35          0.169496  0.266526   0.224733  0.361418  0.330464  0.341412
# 40          0.175610  0.289128   0.314466  0.315725  0.321702  0.297294
# 45          0.202591  0.286101   0.309320  0.278722  0.351104  0.304240
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# ...

# %%
# Generate the Plot (with Error Bars)
plt.errorbar(met_mean_pivot.index, met_mean_pivot["Capomulin"], yerr=met_sem_pivot["Capomulin"], 
             color="r", marker="o", markersize=5, linestyle="dashed", linewidth=0.50)
plt.errorbar(met_mean_pivot.index, met_mean_pivot["Infubinol"], yerr=met_sem_pivot["Infubinol"], 
             color="b", marker="^", markersize=5, linestyle="dashed", linewidth=0.50)
plt.errorbar(met_mean_pivot.index, met_mean_pivot["Ketapril"], yerr=met_sem_pivot["Ketapril"], 
             color="g", marker="s", markersize=5, linestyle="dashed", linewidth=0.50)
plt.errorbar(met_mean_pivot.index, met_mean_pivot["Placebo"], yerr=met_sem_pivot["Placebo"], 
             color="k", marker="d", markersize=5, linestyle="dashed", linewidth=0.50)

plt.title("Metastatic Spread During Treatment")
plt.ylabel("Met. Sites")
plt.xlabel("Treatment Duration (Days)")
plt.grid(True)
plt.legend(loc="best", fontsize="small", fancybox=True)

# Save the Figure
plt.savefig("Analysis/Fig2.png")

# Show the Figure
plt.show()

# %% [markdown]
# ## Survival Rates

# %%
# Store the Count of Mice Grouped by Drug and Timepoint (W can pass any metric)
survival = combined_data.groupby(["Drug", "Timepoint"]).count()["Tumor Volume (mm3)"]

# Convert to DataFrame
survival = pd.DataFrame({"Mouse Count": survival})

# Preview DataFrame
survival.head()
# Out:
#                      Mouse Count
# Drug      Timepoint
# Capomulin 0                   25
#           5                   25
#           10                  25
#           15                  24
#           20                  23

# %%
# Minor Data Munging to Re-Format the Data Frames
survival_pivot = pd.pivot_table(survival, index='Timepoint', columns='Drug', values='Mouse Count', aggfunc = np.mean)

# Preview the Data Frame
survival_pivot
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol  Placebo  \
# Timepoint
# 0                 25        25         25        25        25       25
# 5                 25        21         25        23        23       24
# 10                25        20         21        22        21       24
# 15                24        19         21        19        21       20
# 20                23        18         20        19        20       19
# 25                22        18         18        19        18       17
# 30                22        16         17        18        15       15
# 35                22        14         12        17        15       14
# 40                21        14         10        15        15       12
# 45                21        13          9        11        13       11
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0                26        25        26         25
# 5                25        25        25         24
# ...

# %%
survival_pivot.head()
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol  Placebo  \
# Timepoint
# 0                 25        25         25        25        25       25
# 5                 25        21         25        23        23       24
# 10                25        20         21        22        21       24
# 15                24        19         21        19        21       20
# 20                23        18         20        19        20       19
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0                26        25        26         25
# 5                25        25        25         24
# 10               23        24        23         22
# 15               17        24        23         21
# 20               17        23        21         17

# %%
# Generate the Plot (Accounting for percentages)
plt.plot(100 * survival_pivot["Capomulin"] / 25, color="r", marker="o", 
         linestyle="dashed", markersize=5, linewidth=0.50)
plt.plot(100 * survival_pivot["Infubinol"] / 25, color="b", marker="^", 
         linestyle="dashed", markersize=5, linewidth=0.50)
plt.plot(100 * survival_pivot["Ketapril"] / 25, color="g", marker="s", 
         linestyle="dashed", markersize=5, linewidth=0.50)
plt.plot(100 * survival_pivot["Placebo"] / 25 , color="k", marker="d", 
         linestyle="dashed", markersize=5, linewidth=0.50)
plt.title("Survival During Treatment")
plt.ylabel("Survival Rate (%)")
plt.xlabel("Time (Days)")
plt.grid(True)
plt.legend(loc="best", fontsize="small", fancybox=True)

# Save the Figure
plt.savefig("Analysis/Fig3.png")

# Show the Figure
plt.show()

# %% [markdown]
# ## Summary Bar Graph

# %%
# Calculate the percent changes for each drug
tumor_pct_change = (tumor_mean_pivot.iloc[-1] - tumor_mean_pivot.iloc[0]) / tumor_mean_pivot.iloc[0] *100



# Display the data to confirm
tumor_pct_change
# Out:
# Drug
# Capomulin   -19.475303
# Ceftamin     42.516492
# Infubinol    46.123472
# Ketapril     57.028795
# Naftisol     53.923347
# Placebo      51.297960
# Propriva     47.241175
# Ramicane    -22.320900
# Stelasyn     52.085134
# Zoniferol    46.579751
# dtype: float64

# %%
#I don't think this part was needed.. the series prints with 'inf' in the value column so I'm just leaving it out
#tumor_pct_change_sem = (tumor_sem_pivot.iloc[-1] - tumor_sem_pivot.iloc[0]) / tumor_sem_pivot.iloc[0] *100
#tumor_pct_change_sem

# %%
# Store all Relevant Percent Changes into a Tuple
percent_tuple = (tumor_pct_change["Capomulin"],
                 tumor_pct_change["Infubinol"],
                 tumor_pct_change["Ketapril"],
                 tumor_pct_change["Placebo"])
print(percent_tuple)

# # Splice the data between passing and failing drugs


# # Orient widths. Add labels, tick marks, etc. 
tick_marks = ["Capomulin","Infubinol", "Ketapril","Placebo"]
plt.bar(tick_marks[0], tumor_pct_change[0],color = 'g', align = "center")
plt.bar(tick_marks[1], tumor_pct_change[2],color = 'r', align = "center")
plt.bar(tick_marks[2], tumor_pct_change[3],color = 'r', align = "center")
plt.bar(tick_marks[3], tumor_pct_change[5],color = 'r', align = "center")
plt.grid()
plt.xlabel("Drug Treatment")
plt.ylabel("% Tumor Volume Change")
plt.title("Tumore Change Over 45 Day Treatment")

#plt.yticks(np.arange(-20,60, step =20)
# # Use functions to label the percentages of changes


# Call functions to implement the function calls


# Save the Figure
plt.savefig("Analysis/Fig4.png")

# Show the Figure
plt.show()
# Out:
# (-19.475302667894155, 46.12347172785184, 57.02879468660604, 51.29796048315153)

# %% [markdown]
# # Observable Trends
#
#  ## 1. Treatments using Capomulin and Ramicane show reduction in tumor size (19% and 22% respectively) while other treatments show more than 40% growth.
#
#  ## 2. Treatments using Capomulin and Ramicane demonstrated slower spread of Metastatic sites than other treatments.
#
#  ## 3. Over the time period, treatments using Capomulin and Ramicane had the highest survival rates (21 and 20 mice, respectively) over any other treatment.
